# %%
# Read CSV files using Auto Loader
df = (spark.readStream
  .format("cloudFiles")
  .option("cloudFiles.format", "csv")
  .option("cloudFiles.schemaLocation", "/Volumes/retail_q/volumes/blob_source/_schema")
  .option("header", "true")
  .option("inferSchema", "true")
  .load("/Volumes/retail_q/volumes/blob_source/transactions_source/")
)

# Write to bronze table - process available data and stop
query = (df.writeStream
  .option("checkpointLocation", "/Volumes/retail_q/volumes/blob_source/_checkpoint")
  .trigger(availableNow=True)
  .toTable("retail_q.blob_bronze.transactions")
)

# Wait for the batch to complete
query.awaitTermination()

# %%
# %sql
select count(*) from retail_q.blob_bronze.transactions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(*)</th></tr></thead><tbody><tr><td>2200</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM retail_q.salesforce_bronze.account;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>51</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM retail_q.salesforce_bronze.opportunity;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>100</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) FROM retail_q.postgres_bronze.product_catalog;

# %%
# %sql
SELECT COUNT(*) FROM retail_q.postgres_bronze.inventory;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>40</td></tr></tbody></table></div>
